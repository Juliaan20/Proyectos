# %% [markdown]
# **Predicción del precio de las computadoras portátiles**
#
# El conjunto de datos simula los precios de las computadoras portátiles, capturando diversas características comúnmente asociadas con ellas y sus correspondientes precios simulados. El conjunto de datos abarca atributos clave como la marca, la velocidad del procesador, el tamaño de la RAM, la capacidad de almacenamiento, el tamaño de la pantalla y el peso.

# %%
# Importamos las librerias basicas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Cargamos el dataset
df = pd.read_csv('/content/Laptop_price.csv')
df
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 0      Asus         3.830296        16               512    11.185147
# 1      Acer         2.912833         4              1000    11.311372
# 2    Lenovo         3.241627         4               256    11.853023
# 3      Acer         3.806248        16               512    12.280360
# 4      Acer         3.268097        32              1000    14.990877
# ..      ...              ...       ...               ...          ...
# 995      HP         3.343584         4              1000    12.587095
# 996    Dell         2.780555         8               256    12.679356
# 997    Dell         3.200569         4               512    12.666315
# 998    Asus         1.604182         8               256    11.215581
# 999  Lenovo         1.711980         4               256    16.561498
#
#        Weight         Price
# 0    2.641094  17395.093065
# 1    3.260012  31607.605919
# 2    2.029061   9291.023542
# ...

# %%
# Ver las 10 primera filas
df.head(10)
# Out:
#     Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight  \
# 0    Asus         3.830296        16               512    11.185147  2.641094
# 1    Acer         2.912833         4              1000    11.311372  3.260012
# 2  Lenovo         3.241627         4               256    11.853023  2.029061
# 3    Acer         3.806248        16               512    12.280360  4.573865
# 4    Acer         3.268097        32              1000    14.990877  4.193472
# 5      HP         1.881348        16               256    11.943958  4.840268
# 6  Lenovo         2.940721        32               256    11.713246  4.344846
# 7  Lenovo         3.016788         4               256    15.588315  2.941120
# 8  Lenovo         2.560327         4               512    15.026332  2.743620
# 9    Acer         3.341111        32               512    13.611945  4.093149
#
#           Price
# 0  17395.093065
# 1  31607.605919
# 2   9291.023542
# 3  17436.728334
# 4  32917.990718
# ...

# %%
# Ver informaciòn del dataset
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             1000 non-null   object
#  1   Processor_Speed   1000 non-null   float64
#  2   RAM_Size          1000 non-null   int64
#  3   Storage_Capacity  1000 non-null   int64
#  4   Screen_Size       1000 non-null   float64
#  5   Weight            1000 non-null   float64
#  6   Price             1000 non-null   float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 54.8+ KB
#        Processor_Speed     RAM_Size  Storage_Capacity  Screen_Size  \
# count      1000.000000  1000.000000       1000.000000  1000.000000
# mean          2.750611    15.500000        584.576000    14.056790
# std           0.731796    10.988665        313.438517     1.705882
# min           1.511580     4.000000        256.000000    11.012111
# ...

# %%
# Ver las dimensiones del dataset
df.shape
# Out:
# (1000, 7)

# %%
# Ver si hay datos NAN
df.isnull().sum()
# Out:
# Brand               0
# Processor_Speed     0
# RAM_Size            0
# Storage_Capacity    0
# Screen_Size         0
# Weight              0
# Price               0
# dtype: int64

# %%
# Ver los valores duplicados, como no hay podemos seguir...
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head(2)
# Out:
#   Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight  \
# 0  Asus         3.830296        16               512    11.185147  2.641094
# 1  Acer         2.912833         4              1000    11.311372  3.260012
#
#           Price
# 0  17395.093065
# 1  31607.605919
